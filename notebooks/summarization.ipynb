# %%
#loading the reduced dataset
df_train = pd.read_csv("train_small.csv")
df_test = pd.read_csv("test_small.csv")

# %%
label_map = {1: "negative", 2: "positive"}

df_train["sentiment_text"] = df_train["label"].map(label_map)
df_test["sentiment_text"]  = df_test["label"].map(label_map)

df_train[["label", "sentiment_text"]].head()
# Out:
#    label sentiment_text
# 0      2       positive
# 1      2       positive
# 2      1       negative
# 3      2       positive
# 4      2       positive

# %%
df_train_small["clean_review"] = df_train_small["review"].apply(clean_text)
df_test_small["clean_review"]  = df_test_small["review"].apply(clean_text)

# %%
df_train_small.to_csv("train_small.csv", index=False)
df_test_small.to_csv("test_small.csv", index=False)

# %%
# !pip install sumy
from sumy.parsers.plaintext import PlaintextParser
from sumy.nlp.tokenizers import Tokenizer
from sumy.summarizers.text_rank import TextRankSummarizer

def summarize_text(text, sentences_count=5):
    parser = PlaintextParser.from_string(text, Tokenizer("english"))
    summarizer = TextRankSummarizer()
    summary = summarizer(parser.document, sentences_count)
    
    return " ".join(str(sentence) for sentence in summary)
text_pos = " ".join(
    df_train_small[df_train_small['label']==2]['clean_review'].sample(800)
)

summary_pos = summarize_text(text_pos, sentences_count=5)
print("Positive Summary:\n", summary_pos)
text_neg = " ".join(
    df_train_small[df_train_small['label']==1]['clean_review'].sample(800)
)

summary_neg = summarize_text(text_neg, sentences_count=5)
print("Negative Summary:\n", summary_neg)
# Out:
# Collecting sumy
#   Downloading sumy-0.11.0-py2.py3-none-any.whl.metadata (7.5 kB)
# Collecting docopt<0.7,>=0.6.1 (from sumy)
#   Downloading docopt-0.6.2.tar.gz (25 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting breadability>=0.1.20 (from sumy)
#   Downloading breadability-0.1.20.tar.gz (32 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests>=2.7.0 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from sumy) (2.31.0)
# Collecting pycountry>=18.2.23 (from sumy)
#   Downloading pycountry-24.6.1-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: nltk>=3.0.2 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from sumy) (3.8.1)
# Requirement already satisfied: chardet in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from breadability>=0.1.20->sumy) (4.0.0)
# Requirement already satisfied: lxml>=2.0 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from breadability>=0.1.20->sumy) (4.9.3)
# Requirement already satisfied: click in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from nltk>=3.0.2->sumy) (8.0.4)
# Requirement already satisfied: joblib in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from nltk>=3.0.2->sumy) (1.2.0)
# Requirement already satisfied: regex>=2021.8.3 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from nltk>=3.0.2->sumy) (2022.7.9)
# Requirement already satisfied: tqdm in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from nltk>=3.0.2->sumy) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from requests>=2.7.0->sumy) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from requests>=2.7.0->sumy) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/varsharavi/anaconda3/lib/python3.11/site-packages (from requests>=2.7.0->sumy) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users